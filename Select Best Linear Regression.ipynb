# %% [markdown]
# # Selecting the best regression model
#
# [Data source](https://www.kaggle.com/junkal/selecting-the-best-regression-model/data)

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Exploratory analysis and data pre-processing

# %% [markdown]
# ### Load and read dataset from local hard-disk

# %%
house_data = pd.read_csv('datasets/kc_house_data.csv')
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Shape of datasets

# %%
house_data.shape
# Out:
# (21613, 21)

# %% [markdown]
# ### Info of datasets

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ### Checking `NaN` Values

# %%
house_data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ## 2. Feature's Engineering

# %% [markdown]
# ### Convert data types in suitable for  Regression model

# %%
house_data['date'] = pd.to_datetime(house_data['date'])
house_data = house_data.set_index('id')

house_data.price = house_data.price.astype(int)
house_data.bathrooms = house_data.bathrooms.astype(int)
house_data.floors = house_data.floors.astype(int)

# %%
house_data.head()
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3          1         1180      5650
# 6414100192 2014-12-09  538000         3          2         2570      7242
# 5631500400 2015-02-25  180000         2          1          770     10000
# 2487200875 2014-12-09  604000         4          3         1960      5000
# 1954400510 2015-02-18  510000         3          2         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520       1           0     0          3      7        1180
# 6414100192       2           0     0          3      7        2170
# 5631500400       1           0     0          3      6         770
# 2487200875       1           0     0          5      7        1050
# 1954400510       1           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %% [markdown]
# ### Find age of building and also `Label encoded` to `yr_renovates` and remove `irrelevante columns`

# %%
house_data['house_age'] = house_data['date'].dt.year - house_data['yr_built']
house_data['renovated'] = house_data['yr_renovated'].apply(lambda x:0 if x == 0 else 1)

house_data = house_data.drop('date', axis =1)
house_data = house_data.drop('yr_renovated', axis=1)
house_data = house_data.drop('yr_built', axis=1)

house_data.head()
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900         3          1         1180      5650       1
# 6414100192  538000         3          2         2570      7242       2
# 5631500400  180000         2          1          770     10000       1
# 2487200875  604000         4          3         1960      5000       1
# 1954400510  510000         3          2         1680      8080       1
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
#             zipcode      lat     long  sqft_living15  sqft_lot15  house_age  \
# id
# 7129300520    98178  47.5112 -122.257           1340        5650         59
# 6414100192    98125  47.7210 -122.319           1690        7639         63
# 5631500400    98028  47.7379 -122.233           2720        8062         82
# 2487200875    98136  47.5208 -122.393           1360        5000         49
# 1954400510    98074  47.6168 -122.045           1800        7503         28
#
#             renovated
# id
# 7129300520          0
# 6414100192          1
# 5631500400          0
# 2487200875          0
# 1954400510          0

# %% [markdown]
# ### Shape of dataset

# %%
house_data.shape
# Out:
# (21613, 19)

# %% [markdown]
# ### Find `count`, `mean`, `std` etc up to two decimale digits

# %%
pd.set_option('precision', 2)

house_data.describe().T
# Out:
#                  count      mean        std       min        25%        50%  \
# sqft_basement           1.00  7.48e-02  1.11e-01 -0.14       2.00e-01
# zipcode                 0.07  1.00e+00  2.67e-01 -0.56      -2.79e-01
# lat                     0.11  2.67e-01  1.00e+00 -0.14       4.89e-02
# long                   -0.14 -5.64e-01 -1.36e-01  1.00       3.35e-01
# sqft_living15           0.20 -2.79e-01  4.89e-02  0.33       1.00e+00
# sqft_lot15              0.02 -1.47e-01 -8.64e-02  0.25       1.83e-01
# house_age               0.13  3.47e-01  1.48e-01 -0.41      -3.27e-01
# renovated               0.07  6.43e-02  2.93e-02 -0.07      -2.76e-03
#
#                sqft_lot15  house_age  renovated
# price            8.24e-02      -0.05   1.26e-01
# bedrooms         2.92e-02      -0.15   1.86e-02
# bathrooms        8.08e-02      -0.43   6.00e-02
# sqft_living      1.83e-01      -0.32   5.51e-02
# sqft_lot         7.19e-01      -0.05   7.75e-03
# floors          -1.33e-02      -0.58  -7.85e-03
# waterfront       3.07e-02       0.03   9.33e-02
# view             7.26e-02       0.05   1.04e-01
# condition       -3.41e-03       0.36  -6.01e-02
# grade            1.19e-01      -0.45   1.40e-02
# sqft_above       1.94e-01      -0.42   2.32e-02
# sqft_basement    1.73e-02       0.13   7.10e-02
# zipcode         -1.47e-01       0.35   6.43e-02
# lat             -8.64e-02       0.15   2.93e-02
# long             2.54e-01      -0.41  -6.84e-02
# sqft_living15    1.83e-01      -0.33  -2.76e-03
# sqft_lot15       1.00e+00      -0.07   7.92e-03
# house_age       -7.10e-02       1.00   2.25e-01
# renovated        7.92e-03       0.22   1.00e+00

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(correlation, cbar = True, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ## 3. Baseline algorithm test
#
# ### Split dataset into traing and testing set

# %%
target = house_data['price']
features = house_data.drop(['price', 'lat', 'long'], axis=1)

# %% [markdown]
# ### Find top ten most relevant feature's columns by using RFE
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html

# %%
from sklearn.linear_model import LinearRegression
linearRegression = LinearRegression(normalize = True)

from sklearn.feature_selection import RFE
rfe = RFE(estimator = linearRegression, n_features_to_select = 10, step = 1)
rfe.fit(features,target)
#RFE?
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#   n_features_to_select=10, step=1, verbose=0)

# %% [markdown]
# ### Most relevant features selected

# %%
recursive_features = features.columns[rfe.support_]
recursive_features
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'house_age', 'renovated'],
#       dtype='object')

# %%
X = features[recursive_features]
X.head()
# Out:
#             bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# id
# 7129300520         3          1         1180       1           0     0
# 6414100192         3          2         2570       2           0     0
# 5631500400         2          1          770       1           0     0
# 2487200875         4          3         1960       1           0     0
# 1954400510         3          2         1680       1           0     0
#
#             condition  grade  house_age  renovated
# id
# 7129300520          3      7         59          0
# 6414100192          3      7         63          1
# 5631500400          3      6         82          0
# 2487200875          5      7         49          0
# 1954400510          3      8         28          0

# %%
X = X.values
y = target.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state =21)

# %%
def best_model(model, X_train, y_train, X_test, y_test):
    
    
    model = model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print('Training score :{}'.format(model.score(X_train, y_train)))
    print('Testing score: {}'.format(r2_score(y_test, y_pred)))
    print('r2_score: {}'.format(r2_score(y_test, y_pred)))
    
    return y_pred, y_test

# %% [markdown]
# ### Learning curve function
#
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


def draw_learning_curves(X, y, estimator, cv=None):
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, train_sizes=np.linspace(.1, 1.0, 5))
    plt.figure(figsize=(12,8))

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.grid(True)

    plt.title("Learning Curves", fontsize=22)
    plt.xlabel("Training examples")
    plt.ylabel("Score")

    plt.plot(train_scores_mean, 'o-', color="g",
             label="Training score")
    plt.plot(test_scores_mean, 'o-', color="y",
             label="Cross-validation score")


    plt.legend(loc="best")

    plt.show()
    return train_scores_mean, test_scores_mean

# %% [markdown]
# ### Cross validation

# %%
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

# %% [markdown]
# ### Import models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor


from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Linear Regression model
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
linear_regression = LinearRegression()
y_pred, y_test = best_model(linear_regression, X_train, y_train, X_test, y_test)


df = pd.DataFrame({'Test': y_test, 'Predicted': y_pred})
df.sample(10)
# Out:
# Training score :0.6513744779893144
# Testing score: 0.6618464047555934
# r2_score: 0.6618464047555934
#          Test  Predicted
# 3656   386380   2.75e+05
# 464   1810000   1.03e+06
# 213   2900000   1.53e+06
# 2912   248000   4.12e+05
# 1315   284000   3.26e+05
# 865    375000   2.17e+05
# 1129   253500   4.04e+05
# 2302   497000   4.00e+05
# 3988   225000   1.83e+05
# 3171   540000   4.98e+05

# %% [markdown]
# ### Graphical view of test values vs predicted values, (Only 20 - 20 data points are taken)

# %%
plt.figure(figsize=(20, 10))

plt.plot(y_test[:20], label='Test')
plt.plot(y_pred[:20], label='Predicted')
plt.legend()
plt.title('Linear Regression Prediction', fontsize=25)
plt.show()

# %% [markdown]
# ### Learning curve for Linear regression
#
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html
#
# #### By the observation of diagram and mean training and testing score we find that this model is right fit beacuse at last training score and testing score aprox.

# %%
train_score, test_score = draw_learning_curves(X_train, y_train, linear_regression, cv)

# %%
print('Training score mean: ', train_score)
print('Testing score mean: ', test_score)
# Out:
# Training score mean:  [0.65890236 0.65314101 0.65264934 0.65241949 0.65180397]
# Testing score mean:  [0.6378003  0.64549374 0.64678839 0.64782765 0.64833812]

# %% [markdown]
# ### Importing libraries for DecisionTreeRegression
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error 
from sklearn.metrics import mean_squared_log_error

from sklearn.model_selection import learning_curve

# %% [markdown]
# ### Predict values by DecisionTreeRegression

# %%
decision_tree_estimator = DecisionTreeRegressor()
y_pred, y_test = best_model(decision_tree_estimator, X_train, y_train, X_test, y_test)
df = pd.DataFrame({'Test': y_test, 'Predicted': y_pred})
df.sample(10)
# Out:
# Training score :0.9969916074712795
# Testing score: 0.4732563468928773
# r2_score: 0.4732563468928773
#         Test  Predicted
# 1742  461000   700000.0
# 433   320000   254000.0
# 1261  389000   477000.0
# 2720  350000   445000.0
# 1794  200000   285000.0
# 3459  919950   890776.0
# 3321  455000   287000.0
# 961   810000   320000.0
# 2499  518000   340000.0
# 2709  417000   200000.0

# %% [markdown]
# ### Find estimator score using cross-validation score
#
# https://scikit-learn.org/stable/modules/cross_validation.html

# %%
estimator_score = cross_val_score(decision_tree_estimator, X_train, y_train, cv=5)
estimator_score
# Out:
# array([0.35433253, 0.43071566, 0.43363517, 0.49755347, 0.49011561])

# %% [markdown]
# ### Graphical view of test values vs predicted values, (Only 20 - 20 data points are taken)

# %%
plt.figure(figsize=(20, 10))

plt.plot(y_test[:20], label='test')
plt.plot(y_pred[:20], label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### Learning curve for Decision tree regression
#
# #### By the observation of diagram and mean training and testing score we find that this model goes to over fit

# %%
train_score, test_score = draw_learning_curves(X_train, y_train, decision_tree_estimator, cv)

# %%
print('Training score mean', train_score)
print('Testing score mean', test_score)
# Out:
# Training score mean [0.99973346 0.99918992 0.99860815 0.99805434 0.99752986]
# Testing score mean [0.38424681 0.41795868 0.43132233 0.43621077 0.43607821]

# %% [markdown]
# ### KNeighborsRegressor
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html

# %%
k_neighbios_estimator = KNeighborsRegressor()
y_pred, y_test = best_model(k_neighbios_estimator, X_train, y_train, X_test, y_test)
df = pd.DataFrame({'Test': y_test, 'Predicted': y_pred})
df.sample(10)
# Out:
# Training score :0.6779464581570667
# Testing score: 0.5230855035265762
# r2_score: 0.5230855035265762
#          Test  Predicted
# 1676   258000   2.70e+05
# 2312   298000   3.15e+05
# 2610  1785000   2.63e+06
# 1576   246000   5.72e+05
# 1786   682000   5.33e+05
# 4140   525000   3.51e+05
# 1858   315000   4.08e+05
# 1098   375000   3.16e+05
# 3466  1620500   9.38e+05
# 2257  1015000   8.08e+05

# %%
plt.figure(figsize=(20, 10))

plt.plot(y_test[:20], label='test')
plt.plot(y_pred[:20], label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### Learning curve for KNeighborRegression
#
#
# #### By the observation of diagram and mean training and testing score we find that this model just under fit

# %%
train_score, test_score = draw_learning_curves(X_train, y_train, k_neighbios_estimator, cv)

# %%
print('Training score mean', train_score)
print('Testing score mean', test_score)
# Out:
# Training score mean [0.64622055 0.66238552 0.67357474 0.67572272 0.67629465]
# Testing score mean [0.46756275 0.4837349  0.49249113 0.5015367  0.50561616]

# %% [markdown]
# ### GradientBoostingRegressor
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

# %%
gb_regressor = GradientBoostingRegressor()
y_pred, y_test = best_model(gb_regressor, X_train, y_train, X_test, y_test)
df = pd.DataFrame({'Test': y_test, 'Predicted': y_pred})
df.sample(10)
# Out:
# Training score :0.7666224798940087
# Testing score: 0.7191975272420172
# r2_score: 0.7191975272420172
#         Test  Predicted
# 438   226740  325908.91
# 695   274900  333815.16
# 1244  487000  328678.68
# 4132  489900  469107.50
# 3687  953007  765006.86
# 452   152000  270128.56
# 1498  775000  848301.92
# 1665  849000  774123.46
# 780   425000  276232.85
# 707   240000  529088.59

# %%
plt.figure(figsize=(20, 10))

plt.plot(y_test[:20], label='test')
plt.plot(y_pred[:20], label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### Learning curve for GradientBostingRegression
#
# #### By the observation of diagram and mean training and testing score we find that this model goes to best fit

# %%
train_score, test_score = draw_learning_curves(X_train, y_train, gb_regressor, cv)

# %%
print('Training score mean', train_score)
print('Testing score mean', test_score)
# Out:
# Training score mean [0.84793653 0.80229909 0.78842487 0.77899061 0.77190959]
# Testing score mean [0.66372192 0.69509922 0.70492003 0.70719288 0.71128159]
